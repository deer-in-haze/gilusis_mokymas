# %%
from importlib import reload
import src.ai_misko_asistentas.util.data_display as data_display
data_display = reload(data_display)

# %%
data_display.show_data_table("plant_examples.csv")
# Out:
# Loading CSV: plant_examples.csv
# Loading CSV: /Users/migle.lukoseviciute/PycharmProjects/gilusis_mokymas/data
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Image</th>
#       <th>Latin name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..." width="120" style="border-radius:10px;" alt="rubus_idaeus.jpg"></td>
#       <td>rubus idaeus</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..." width="120" style="border-radius:10px;" alt="amanita_muscaria.jpg"></td>
#       <td>amanita muscaria</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..." width="120" style="border-radius:10px;" alt="cantharellus_cibarius.jpg"></td>
#       <td>cantharellus cibarius</td>
#     </tr>
#     <tr>
#       <td><img src="data:image/jpeg;base64,..." width="120" style="border-radius:10px;" alt="vaccinium_myrtillus.jpg"></td>
# ...
